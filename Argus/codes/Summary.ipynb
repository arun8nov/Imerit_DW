# %%
import pandas as pd

# %%
df = pd.read_csv(r"D:\GIT\Imerit_DW\Argus\Data\Op_Tracker.csv")

# %%
df.pivot_table(index="Assignee",columns="Date",values="Actual Time [Min]",aggfunc=sum)
# Out:
# Date                           2026-03-26  2026-03-30  2026-03-31  2026-04-01  \
# Assignee
# abdul.bas@imerit.net                  0.0  117.811200   39.868133         NaN
# amirtha.m@imerit.net                  0.0  169.530717   43.437733         NaN
# anusiya.j@imerit.net                  NaN  204.877667   90.347217         NaN
# arunprakash.b@imerit.net              0.0  105.502817         NaN         NaN
# chandru.s@imerit.net                  NaN  135.788717   51.731450         NaN
# charrukesi.s@imerit.net               0.0  133.265183   38.414767         NaN
# dhivya.s@imerit.net                   0.0  115.305850   33.490400         NaN
# divya.s1@imerit.net                   NaN  124.075733   57.563133         NaN
# hariprasath.k@imerit.net              0.0  137.616350   52.625383         NaN
# harshavardhini.h@imerit.net           0.0  124.673517         NaN         NaN
# jenipher.g@imerit.net                 0.0  132.567433   30.386317         NaN
# ...
