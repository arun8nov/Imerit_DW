# %%
# %pip install openpyxl
import pandas as pd
import openpyxl
# Out:
# Note: you may need to restart the kernel to use updated packages.
# c:\Users\arun.prakash\Downloads\Vs Folders\Imerit_DW\.venv\Scripts\python.exe: No module named pip
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 3
#       1 get_ipython().run_line_magic('pip', 'install openpyxl')
#       2 import pandas as pd
# ----> 3 import openpyxl
#
# ModuleNotFoundError: No module named 'openpyxl'

# %%
df = pd.read_excel(r"C:\Users\arun.prakash\Downloads\Vs Folders\Imerit_DW\Argus\Data\xlsx_files\Copy of Task Tracker_April 13_7 30 PM.xlsx")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File c:\Users\arun.prakash\Downloads\Vs Folders\Imerit_DW\.venv\Lib\site-packages\pandas\compat\_optional.py:158, in import_optional_dependency(name, extra, min_version, errors)
#     157 try:
# --> 158     module = importlib.import_module(name)
#     159 except ImportError as err:
#
# File ~\AppData\Roaming\uv\python\cpython-3.14-windows-x86_64-none\Lib\importlib\__init__.py:88, in import_module(name, package)
#      87         level += 1
# ---> 88 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1398, in _gcd_import(name, package, level)
#    1396     if level > 0:
#    1397         name = _resolve_name(name, package, level)
# -> 1398     return _find_and_load(name, _gcd_import)
#
# File <frozen importlib._bootstrap>:1371, in _find_and_load(name, import_)
# ...
